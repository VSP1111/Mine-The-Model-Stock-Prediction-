# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
# %matplotlib inline
def lstm_model1(path):
     df = pd.read_csv(path)
     df1 = df.reset_index()['Close']
     from sklearn.preprocessing import MinMaxScaler
     scaler = MinMaxScaler(feature_range = (0,1))
     df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))
     training_size =  2400
     test_size = 600
     train_data , test_data = df1[0:training_size,:],df1[training_size :, :1]
     def create_dataset(dataset , time_step = 250):
       dataX , dataY = [] , []
       for j in range(len(dataset)-time_step-1):
         a= dataset[j:(j+time_step),0]
         dataX.append(a)
         dataY.append(dataset[j + time_step , 0])
       return np.array(dataX), np.array(dataY)
     time_step = 250
     X_train , y_train = create_dataset(train_data , time_step)
     X_test , y_test = create_dataset(test_data , time_step)
     X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
     X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
     import tensorflow as tf
     from tensorflow.keras.models import Sequential
     from tensorflow.keras.layers import Dense
     from tensorflow.keras.layers import LSTM
     regressor = Sequential()
     from keras.models import Sequential
     from keras.layers import Dense
     from keras.layers import SimpleRNN
     from keras.layers import Dropout
# adding first RNN layer and dropout regulatization
     regressor.add(
              SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True, 
              input_shape = (X_train.shape[1],1))
             )

     regressor.add(
      Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

     regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

     regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

     regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

     regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

     regressor.add(
    SimpleRNN(units = 50)
             )

     regressor.add(
    Dropout(0.2)
             )

# adding the output layer
     regressor.add(Dense(units = 1))

# compiling RNN
     regressor.compile(
    optimizer = "adam", 
    loss = "mean_squared_error",
    metrics = ["accuracy"])
     regressor.fit(X_train,y_train , validation_data=(X_test,y_test),epochs = 100 , batch_size=64)
     train_predict = regressor.predict(X_train)
     test_predict = regressor.predict(X_test)
     train_predict = scaler.inverse_transform(train_predict)
     test_predict = scaler.inverse_transform(test_predict)
     x_input = test_data[350:].reshape(1,-1)
     temp_input = list(x_input)
     lst_output = []
     n_steps = 250
     k=0
     while(k<100):
       if(len(temp_input)>250):
         x_input = np.array(temp_input[1:])

         x_input = x_input.reshape((1, n_steps , 1))
         yhat = regressor.predict(x_input,verbose = 0)

         temp_input.extend(yhat[0].tolist())
         temp_input = temp_input[1:]
         lst_output.extend(yhat.tolist())
         k=k+1
       else:
         x_input = x_input.reshape((1,n_steps,1))
         yhat = regressor.predict(x_input,verbose = 0)
         
         temp_input.extend(yhat[0].tolist())
         lst_output.extend(yhat.tolist())
         k = k +1
     lst_output = scaler.inverse_transform(lst_output) 
     return lst_output
     
dfs = []
predicted_dataframe=[]
folder_path = '/kaggle/input/mine-the-model-2023/Upload-Dataset/TRAIN'
for filename in os.listdir(folder_path):
  stock_df = os.path.join(folder_path,filename)
  predicted_dataframe =lstm_model1(stock_df)
  dfs.append(predicted_dataframe)
x = []
z = [0] * 5000
m = []
for filename in os.listdir(folder_path):
    a = filename[:3] + '_#' 
    for i in range(100):
        y = a + str(i+1)
        x.append(y)
for i in range(50):
    for k in range(100):
        u = 100*i + k
        z[u]  = float(dfs[i][k])
cc = pd.DataFrame({'ID' : x , 'Price' : z})
cc.to_csv('SubmissionVC.csv' ,index = False)
cc
# Out:
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 254ms/step - accuracy: 9.2189e-04 - loss: 0.3886 - val_accuracy: 0.0000e+00 - val_loss: 0.0987
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 247ms/step - accuracy: 0.0000e+00 - loss: 0.1901 - val_accuracy: 0.0000e+00 - val_loss: 0.1617
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 263ms/step - accuracy: 8.3260e-04 - loss: 0.5876 - val_accuracy: 0.0000e+00 - val_loss: 0.2700
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - accuracy: 0.0000e+00 - loss: 0.2525 - val_accuracy: 0.0000e+00 - val_loss: 0.2223
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 247ms/step - accuracy: 0.0000e+00 - loss: 0.5356 - val_accuracy: 0.0029 - val_loss: 0.0439
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 6.9442e-04 - loss: 0.2252 - val_accuracy: 0.0029 - val_loss: 0.0515
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 242ms/step - accuracy: 0.0000e+00 - loss: 0.4021 - val_accuracy: 0.0029 - val_loss: 0.0541
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 225ms/step - accuracy: 0.0000e+00 - loss: 0.2215 - val_accuracy: 0.0000e+00 - val_loss: 0.0897
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 243ms/step - accuracy: 9.8745e-05 - loss: 0.8742 - val_accuracy: 0.0000e+00 - val_loss: 0.0018
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 9.4729e-04 - loss: 0.2175 - val_accuracy: 0.0000e+00 - val_loss: 0.0766
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 262ms/step - accuracy: 8.1357e-04 - loss: 0.2694 - val_accuracy: 0.0000e+00 - val_loss: 0.0025
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - accuracy: 1.8485e-04 - loss: 0.1656 - val_accuracy: 0.0000e+00 - val_loss: 0.0044
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 245ms/step - accuracy: 3.1643e-04 - loss: 0.3722 - val_accuracy: 0.0000e+00 - val_loss: 0.0205
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 230ms/step - accuracy: 5.4069e-05 - loss: 0.2134 - val_accuracy: 0.0000e+00 - val_loss: 5.2268e-04
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 248ms/step - accuracy: 6.5748e-04 - loss: 0.6714 - val_accuracy: 0.0000e+00 - val_loss: 0.0185
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 0.0000e+00 - loss: 0.3248 - val_accuracy: 0.0000e+00 - val_loss: 0.0139
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 251ms/step - accuracy: 7.9018e-04 - loss: 0.6992 - val_accuracy: 0.0000e+00 - val_loss: 0.1074
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 245ms/step - accuracy: 4.8528e-04 - loss: 0.3224 - val_accuracy: 0.0000e+00 - val_loss: 0.0371
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 250ms/step - accuracy: 0.0000e+00 - loss: 0.6173 - val_accuracy: 0.0000e+00 - val_loss: 0.1363
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - accuracy: 0.0000e+00 - loss: 0.3633 - val_accuracy: 0.0000e+00 - val_loss: 0.0093
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 248ms/step - accuracy: 3.1643e-04 - loss: 0.3468 - val_accuracy: 0.0029 - val_loss: 0.0611
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 3.7059e-04 - loss: 0.1932 - val_accuracy: 0.0029 - val_loss: 0.0176
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 244ms/step - accuracy: 0.0000e+00 - loss: 0.4602 - val_accuracy: 0.0000e+00 - val_loss: 0.0430
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 237ms/step - accuracy: 0.0000e+00 - loss: 0.2484 - val_accuracy: 0.0000e+00 - val_loss: 0.0444
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 261ms/step - accuracy: 0.0000e+00 - loss: 0.4028 - val_accuracy: 0.0000e+00 - val_loss: 0.0027
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 236ms/step - accuracy: 1.3122e-04 - loss: 0.2503 - val_accuracy: 0.0000e+00 - val_loss: 0.0388
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 250ms/step - accuracy: 0.0000e+00 - loss: 0.5660 - val_accuracy: 0.0000e+00 - val_loss: 0.0335
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 232ms/step - accuracy: 0.0000e+00 - loss: 0.2642 - val_accuracy: 0.0000e+00 - val_loss: 0.0094
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 256ms/step - accuracy: 5.8901e-04 - loss: 0.6865 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 235ms/step - accuracy: 3.4269e-04 - loss: 0.2657 - val_accuracy: 0.0000e+00 - val_loss: 0.0035
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 252ms/step - accuracy: 0.0019 - loss: 0.3779 - val_accuracy: 0.0057 - val_loss: 0.0466
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.0000e+00 - loss: 0.2282 - val_accuracy: 0.0057 - val_loss: 0.0247
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 252ms/step - accuracy: 1.7498e-04 - loss: 0.6169 - val_accuracy: 0.0000e+00 - val_loss: 0.0114
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 2.4581e-04 - loss: 0.3400 - val_accuracy: 0.0000e+00 - val_loss: 0.0360
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 247ms/step - accuracy: 0.0019 - loss: 0.3773 - val_accuracy: 0.0000e+00 - val_loss: 0.0048
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 5.4437e-04 - loss: 0.2667 - val_accuracy: 0.0000e+00 - val_loss: 0.0708
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 251ms/step - accuracy: 0.0000e+00 - loss: 0.4484 - val_accuracy: 0.0000e+00 - val_loss: 0.1373
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 245ms/step - accuracy: 0.0012 - loss: 0.3202 - val_accuracy: 0.0000e+00 - val_loss: 0.1079
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.0000e+00 - loss: 0.3759 - val_accuracy: 0.0029 - val_loss: 0.0228
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 234ms/step - accuracy: 0.0000e+00 - loss: 0.1494 - val_accuracy: 0.0029 - val_loss: 0.0506
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 254ms/step - accuracy: 0.0000e+00 - loss: 0.4972 - val_accuracy: 0.0000e+00 - val_loss: 0.0030
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.0000e+00 - loss: 0.2563 - val_accuracy: 0.0000e+00 - val_loss: 0.0189
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 255ms/step - accuracy: 7.5820e-04 - loss: 0.4268 - val_accuracy: 0.0029 - val_loss: 0.0277
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 250ms/step - accuracy: 0.0010 - loss: 0.2353 - val_accuracy: 0.0029 - val_loss: 0.0259
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 260ms/step - accuracy: 0.0019 - loss: 0.5574 - val_accuracy: 0.0000e+00 - val_loss: 0.1465
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - accuracy: 0.0000e+00 - loss: 0.2794 - val_accuracy: 0.0029 - val_loss: 0.0118
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 257ms/step - accuracy: 6.3862e-04 - loss: 0.3510 - val_accuracy: 0.0000e+00 - val_loss: 0.2815
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 4.3224e-04 - loss: 0.1815 - val_accuracy: 0.0000e+00 - val_loss: 0.2429
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 5.4069e-05 - loss: 0.3642 - val_accuracy: 0.0000e+00 - val_loss: 0.0600
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 0.0019 - loss: 0.2348 - val_accuracy: 0.0000e+00 - val_loss: 0.0086
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 264ms/step - accuracy: 0.0973 - loss: 0.3916 - val_accuracy: 0.0000e+00 - val_loss: 1.3894e-04
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 0.0951 - loss: 0.2159 - val_accuracy: 0.0000e+00 - val_loss: 3.5424e-04
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 257ms/step - accuracy: 2.6813e-04 - loss: 0.4361 - val_accuracy: 0.0000e+00 - val_loss: 0.0059
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step - accuracy: 2.4581e-04 - loss: 0.2446 - val_accuracy: 0.0000e+00 - val_loss: 0.0190
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 13s 254ms/step - accuracy: 6.8470e-05 - loss: 0.4446 - val_accuracy: 0.0029 - val_loss: 0.1088
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - accuracy: 5.4069e-05 - loss: 0.1984 - val_accuracy: 0.0000e+00 - val_loss: 0.1421
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Epoch 1/2
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 252ms/step - accuracy: 1.6625e-04 - loss: 0.6423 - val_accuracy: 0.0000e+00 - val_loss: 0.2627
# Epoch 2/2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 8.8667e-04 - loss: 0.3121 - val_accuracy: 0.0000e+00 - val_loss: 0.2373
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# /tmp/ipykernel_33/2507586088.py:141: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   z[u]  = float(dfs[i][k])
#             ID      Price
# 0       070_#1  49.354985
# 1       070_#2  49.354985
# 2       070_#3  49.354985
# 3       070_#4  49.354985
# 4       070_#5  49.354985
# ...        ...        ...
# 4995   804_#96   5.669143
# 4996   804_#97   5.669143
# 4997   804_#98   5.669143
# 4998   804_#99   5.669143
# 4999  804_#100   5.669143
#
# [5000 rows x 2 columns]
